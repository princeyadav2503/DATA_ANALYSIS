# %%
import pandas as pd

# %%
df=pd.read_csv("/content/diabetes (1).csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_588/147857430.py in <cell line: 0>()
# ----> 1 df=pd.read_csv("/content/diabetes (1).csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # EXPLORE THE **DATASET**

# %%
# to see top 5 rows  from starting
df.head()

# %%
# to see particular rows  from starting
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_588/405001475.py in <cell line: 0>()
#       1 # to see particular rows  from starting
# ----> 2 df.head(3)
#
# NameError: name 'df' is not defined

# %%
df.tail()

# %%
# to  see the shape of the dataset
df.shape

(768,9)

# %%
# to see the name of the coloumn
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_588/310472343.py in <cell line: 0>()
#       1 # to see the name of the coloumn
# ----> 2 df.columns
#
# NameError: name 'df' is not defined

# %%
# Datatypes of the column
df.dtypes

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# # CHECK DATA **QUALITY**

# %%
df.isnull()

# %%
#check the duplicate value
df.duplicated().sum()

# %%
# to count the unique values
df.nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_588/208803293.py in <cell line: 0>()
#       1 # to count the unique values
# ----> 2 df.nunique()
#
# NameError: name 'df' is not defined

# %%
# to check the invalid zero values(real missing value)
(df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']]==0).sum()

# %%
# select a column
df  ['Glucose']

# %%
#multiple coloumn
df[['Age','BloodPressure']]

# %%
#filter row by some condition
df[df['Age']>60].count()

# %%
# filter with multiple condition
df[(df['Age']>60) & (df['BMI']>30)]

# %%
df[(df['Age']>65) & (df['Outcome']==1)]

# %%
# acess rows by index
df.iloc[2:5]

# %%
#Sort by using a column
df.sort_values(by='Age')

# %%
df['Glucose'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_588/1662164251.py in <cell line: 0>()
# ----> 1 df['Glucose'].value_counts()
#
# NameError: name 'df' is not defined

# %%
# group by and aggregate the data
df.groupby('Outcome').agg({'Glucose':'mean','BMI':'median'})

# %%
df.groupby('Outcome').mean()

# %%
#Statistics
# Mean of the data
df['BMI'].mean()

# %%
#median
df['BMI'].median()

# %%
#Standard Deviation
df['Age'].std()

# %%
# corelation matrix
df.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_588/656733015.py in <cell line: 0>()
#       1 # corelation matrix
# ----> 2 df.corr()
#
# NameError: name 'df' is not defined

# %%
# add new coloumn
df['BMI_CATEGORY']=pd.cut(df['BMI'],bins=[0,18.5,24.9,29.9,100],labels=['Underweight','Normal','Overweight','Obese'])

# %%
df.head(20)

# %%
#Replace invalid zero
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean())

# %% [markdown]
# # DATA **VISUALIZATION**

# %%
#Histogram
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(df['BMI'])
plt.hist(['Age'])
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_588/1056351615.py in <cell line: 0>()
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 4 sns.histplot(df['BMI'])
#       5 plt.hist(['Age'])
#       6 plt.xlabel('Age')
#
# NameError: name 'df' is not defined
